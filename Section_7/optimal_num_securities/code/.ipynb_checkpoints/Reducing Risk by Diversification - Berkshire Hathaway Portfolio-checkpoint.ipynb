# %% [markdown]
# ![Fervent%20Logo%20-%20Video%20Overlay%20%5Bsmall%5D.png](attachment:Fervent%20Logo%20-%20Video%20Overlay%20%5Bsmall%5D.png)
# # Reducing Risk by Diversification - Number of Securities to Hold
# In this walkthrough, you'll explore what the optimal number of securities might be.

# %%
import pandas as pd

# %%
brk_portfolio = pd.read_csv('../data/brk_portfolio.csv')

# %%
sorted_by_weights = brk_portfolio.sort_values(by='weights', ascending=False)

# %%
sorted_by_weights['cumulative_weights'] = sorted_by_weights['weights'].cumsum()

# %%
sorted_by_weights
# Out:
#                                     company symbol   holdings  mkt_price  \
# 1                                Apple Inc.   AAPL  249589329     235.28
# 5                      Bank of America Corp    BAC  947760000      30.26
# 16                             Coca-Cola Co     KO  400000000      53.79
# 44                         Wells Fargo & Co    WFC  409803773      49.61
# 3                  American Express Company    AXP  151610700     119.10
# 15                           Kraft Heinz Co    KHC  325634818      27.77
# 41                             U.S. Bancorp    USB  132459618      54.71
# 14                     JPMorgan Chase & Co.    JPM   59514932     120.35
# 25                      Moody's Corporation    MCO   24669778     218.77
# 12                  Goldman Sachs Group Inc     GS   18353635     206.46
# 9                     Delta Air Lines, Inc.    DAL   70910456      53.37
# 6              Bank of New York Mellon Corp     BK   80937250      44.38
# ...
